# %%
# %load_ext jumper_extension
# Out:
# [JUmPER]: ADLXPybind not available. AMD GPU monitoring disabled.
# [JUmPER]: Perfmonitor extension loaded

# %%
# %perfmonitor_start
# Out:
# [JUmPER]: Performance monitoring started (PID: 3878, Interval: 1.0s)

# %%
import numpy as np

# Some CPU bound code example
size = 7000 
A = np.random.rand(size, size)
B = np.random.rand(size, size)
C = A @ B
C = A @ C

# %%
# %perfmonitor_plot

# %%
# %export_session session_example.zip
# Out:
# [JUmPER]: Exported to session_example.zip
