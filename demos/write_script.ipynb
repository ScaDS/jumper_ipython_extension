# %%
# %load_ext jumper_extension
# Out:
# [JUmPER]: ADLXPybind not available. AMD GPU monitoring disabled.
# [JUmPER]: Perfmonitor extension loaded

# %%
# %perfmonitor_help

# %%
# %perfmonitor_enable_perfreports --interval 1 --level system --text
# Out:
# [JUmPER]: Performance monitoring started (PID: 15358, Interval: 1.0s)
# [JUmPER]: Performance reports enabled for each cell (level: system, interval: 1.0, format: text)

# %%
print("Pre-setup step 1 complete")
x = 42
print(f"Value of x: {x}")
# Out:
# Pre-setup step 1 complete
# Value of x: 42
# [JUmPER]: No performance data available or recorded cells are too short

# %%
# %start_write_script test_output_script.py
# Out:
# [JUmPER]: Started script recording to 'test_output_script.py'

# %%
print("This should be inside the script")
for i in range(3):
    print(f"Counting: {i}")
# Out:
# [JUmPER]: Cell execution skipped during script recording
# [JUmPER]: No performance data available or recorded cells are too short

# %%
# %perfmonitor_enable_perfreports --interval 1 --level system --text
# Out:
# [JUmPER]: Cell execution skipped during script recording

# %%
import numpy as np

size = 7000 
A = np.random.rand(size, size)
B = np.random.rand(size, size)
C = A @ B
C = A @ C
print("CPU-bound test completed. Shape:", C.shape)
# Out:
# [JUmPER]: Cell execution skipped during script recording
# [JUmPER]: No performance data available or recorded cells are too short

# %%
# %perfmonitor_plot
# Out:
# [JUmPER]: Cell execution skipped during script recording

# %%
# %end_write_script
# Out:
# [JUmPER]: Recorded 4 cells to file 'test_output_script.py'
# Script saved to: test_output_script.py

# %%
print("Script writing ended. Notebook execution continues.")
# Out:
# Script writing ended. Notebook execution continues.
# [JUmPER]: No performance data available or recorded cells are too short

# %%
# %show_cell_history
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_62be4758_fef6_40b9_85f9_72f033957cec"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
# ...
